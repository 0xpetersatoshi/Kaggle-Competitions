# %% [markdown]
# # Titanic Kaggle Competition

# %%
# machine learning modules
from sklearn.linear_model import LogisticRegression, Lasso
from sklearn.metrics import roc_auc_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder, Imputer
from sklearn.model_selection import train_test_split, GridSearchCV

# data wrangling, visualization, exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.tools import plotting

# %%
# setup environement
sns.set()
# %matplotlib notebook

# %%
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')

# %% [markdown]
# ## EDA

# %%
train_df.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# Looks like some features are missing some values so we will try to fill those in. `Age` only has 714 values out of 891 so we will fill the missing ones with the `median` age. However, simply filling in the `median` value would not be enough. Instead, we will try to take the `median` of the groups that are closest to the observations with the missing values.

# %%
# group data by Sex and Pclass to estimate a more accurate age for NAs
grouped_sex_class = train_df.groupby(['Sex', 'Pclass'])
grouped_sex_class['Age'].median()
# Out:
# Sex     Pclass
# female  1         35.0
#         2         28.0
#         3         21.5
# male    1         40.0
#         2         30.0
#         3         25.0
# Name: Age, dtype: float64

# %%
# fill NAs with grouped features
train_df['Age'] = grouped_sex_class['Age'].apply(lambda x: x.fillna(x.median()))

# check values
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
# view embarked value counts
train_df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# fill NAs with most frequent value
train_df['Embarked'] = train_df['Embarked'].fillna(train_df['Embarked'].value_counts().index[0])

# %%
train_df.Cabin.value_counts()
# Out:
# B96 B98            4
# C23 C25 C27        4
# G6                 4
# E101               3
# F2                 3
# C22 C26            3
# D                  3
# F33                3
# D17                2
# C65                2
# C124               2
# B20                2
# B77                2
# C52                2
# F4                 2
# E25                2
# B35                2
# F G73              2
# E121               2
# C126               2
# B28                2
# C92                2
# B58 B60            2
# B51 B53 B55        2
# C123               2
# B57 B59 B63 B66    2
# C78                2
# D26                2
# B18                2
# E67                2
#                   ..
# B102               1
# A19                1
# E40                1
# C110               1
# F E69              1
# C45                1
# A16                1
# D15                1
# B101               1
# E58                1
# E34                1
# C111               1
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
_ = plotting.scatter_matrix(train_df[['Survived', 'Pclass', 'Sex', 'Age', 'Ticket', 'Fare']])
plt.show()
# Out:
# /Users/pbegle/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
train_df.Age = train_df.Age.fillna(np.mean(train_df.Age))

# %%
train_df.Embarked = train_df.Embarked.fillna(train_df['Embarked'].value_counts().index[0])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train_df = train_df.drop('Cabin', axis=0)
train_df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-cb8f38fe070f> in <module>()
# ----> 1 train_df = train_df.drop('Cabin', axis=0)
#       2 train_df.info()
#
# /Users/pbegle/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /Users/pbegle/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
# ...
